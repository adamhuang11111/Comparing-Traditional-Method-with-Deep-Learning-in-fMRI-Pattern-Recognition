# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns

# %%
phenotype = pd.read_csv("adhd200_preprocessed_phenotypics.tsv", sep = '\t')

# %%
phenotype
# Out:
#      ScanDir ID  Site  Gender    Age Handedness DX   Secondary Dx  \
# 0       2371032     3     0.0  10.73          1  0            NaN
# 1       2026113     3     0.0  12.99          1  1            NaN
# 2       3434578     3     0.0   8.12          1  0            NaN
# 3       8628223     3     0.0  10.81          1  0  Simple phobia
# 4       1623716     3     0.0  12.65          1  1            NaN
# ..          ...   ...     ...    ...        ... ..            ...
# 968       25008     7     1.0  15.90          1  3            NaN
# 969       25009     7     1.0  13.87          1  0            NaN
# 970       25012     7     0.0  15.04          1  3            NaN
# 971       25013     7     1.0  13.64          1  0            NaN
# 972       25014     7     1.0  13.72          1  3            NaN
#
#     ADHD Measure ADHD Index Inattentive Hyper/Impulsive  IQ Measure  \
# 0              2         47          55              43         1.0
# ...

# %%
beijing_subjects = os.listdir('anat')

# %%
def get_list_subject(subjects):
    for i in range(len(subjects)):
        subjects[i] = [int(s) for s in subjects[i].split("_") if s.isdigit()]
        if(len(subjects[i]) > 0):
            subjects[i] = subjects[i][0]
    subjects = [x for x in subjects if x != []]
    return subjects

# %%
beijing_subjects = get_list_subject(beijing_subjects)

# %%
beijing_phenotype = phenotype[phenotype["ScanDir ID"].isin(beijing_subjects)]
beijing_phenotype
# Out:
#      ScanDir ID  Site  Gender    Age Handedness DX Secondary Dx ADHD Measure  \
# 776     1038415     1     1.0  14.92          1  3          ODD            1
# 777     1201251     1     1.0  12.33          1  3          NaN            1
# 778     1245758     1     0.0   8.58          1  0          NaN            1
# 779     1253411     1     1.0   8.08          1  0          NaN            1
# 780     1419103     1     0.0   9.92          1  0          NaN            1
# 781     1517058     1     1.0   9.75          1  0          NaN            1
# 782     1581470     1     1.0   8.83          1  0          NaN            1
# 783     1784368     1     1.0   8.92          1  3          NaN            1
# 784     1849382     1     1.0  11.67          1  0     enuresis            1
# 785     1854691     1     0.0   8.83          1  0          NaN            1
# 786     1883688     1     0.0   9.08          1  3          NaN            1
# ...

# %%
beijing_phenotype.to_csv("beijing_phenotype.csv")

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 10, 8

# %%
# phenotype_tab = phenotype.dropna(subset = ["ADHD Measure", "Performance IQ"])
# phenotype_tab["ADHD Measure"][852]
phenotype_tab = phenotype_tab[phenotype_tab['Performance IQ'] > 0]

# %%
plt.hist(phenotype_tab["Age"], color = 'purple')
plt.ylabel("number of kids")
plt.xlabel("age")
plt.grid()

# %%
plt.hist(np.array(phenotype_tab["DX"]).astype(np.int), color = 'red')
plt.ylabel("number of kids")
plt.xlabel("diagnosis")
plt.grid()

# %%
sns.boxplot(x = "DX", y = "Performance IQ", data = phenotype_tab)
plt.grid()

# %%
sns.boxplot(x = "DX", y = "Verbal IQ", data = phenotype_tab)
plt.grid()

# %%
plt.scatter(phenotype_tab["Performance IQ"], phenotype_tab["Verbal IQ"], color = 'green')
plt.xlabel("performance IQ")
plt.ylabel("verbal IQ")
plt.grid()

# %%
ohsu_subjects = os.listdir('../ohsu_test_output_nifty/anat')

# %%
ohsu_subjects = get_list_subject(ohsu_subjects)

# %%
nyu_subjects = os.listdir('../nyu_test_output_nifty/anat_nyu_test')

# %%
nyu_subjects = get_list_subject(nyu_subjects)

# %%
experimental_final_table = phenotype[(phenotype["ScanDir ID"].isin(beijing_subjects)) | 
                                     (phenotype["ScanDir ID"].isin(ohsu_subjects)) | 
                                     (phenotype["ScanDir ID"].isin(nyu_subjects))]
experimental_final_table
# Out:
#      ScanDir ID  Site  Gender    Age Handedness DX Secondary Dx ADHD Measure  \
# 776     1038415     1     1.0  14.92          1  3          ODD            1
# 777     1201251     1     1.0  12.33          1  3          NaN            1
# 778     1245758     1     0.0   8.58          1  0          NaN            1
# 779     1253411     1     1.0   8.08          1  0          NaN            1
# 780     1419103     1     0.0   9.92          1  0          NaN            1
# ..          ...   ...     ...    ...        ... ..          ...          ...
# 959       23038     6     1.0   9.33          1  0          NaN          NaN
# 960       23039     6     1.0  11.17          1  0          NaN          NaN
# 961       23040     6     0.0   7.50          1  0          NaN          NaN
# 962       23041     6     0.0   9.92          1  0          NaN          NaN
# 963       23042     6     0.0   8.08          1  0          NaN          NaN
#
# ...

# %%
experimental_final_table.to_csv("final_table.csv")

# %%
plt.hist(experimental_final_table["Age"], color = 'purple')
plt.ylabel("number of kids")
plt.xlabel("age")
plt.grid()

# %%
plt.hist(np.array(experimental_final_table["DX"]).astype(np.int), color = 'red')
plt.ylabel("number of kids")
plt.xlabel("diagnosis")
plt.grid()

# %%
plt.scatter(experimental_final_table["Performance IQ"], experimental_final_table["Verbal IQ"], color = 'green')
plt.xlabel("performance IQ")
plt.ylabel("verbal IQ")
plt.grid()
